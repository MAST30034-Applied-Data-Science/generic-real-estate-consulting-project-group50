# %%
# Out:
#      Unnamed: 0  Postcode                 Centroid  \
# 0             1      3000    -37.817403 144.956776
# 1             4      3002    -37.818517 144.982207
# 2            11      3004    -37.844246 144.970161
# 3            13      3008    -37.814719 144.948039
# 4            16      3011    -37.807101 144.907953
# ..          ...       ...                      ...
# 163         263      3960    -39.140761 146.360412
# 164         264      3976    -38.043995 145.264296
# 165         265      3977  -38.1466398 145.2695101
# 166         266      3981       -38.207298 145.575
# 167         267      3995    -38.578071 145.630713
#
#                                      Formal Name  \
# 0      Melbourne Oral and Facial Surgery Pty Ltd
# 1            East Melbourne Day Procedure Centre
# 2                                  Alfred Health
# 3               Specialist Surgicentre Docklands
# 4                   Vision Day Surgery Footscray
# ...

# %%
data = pd.read_csv('../data/curated/closest_school.csv')
unit = " km"
data['Distance'] = data['Distance'].map(lambda x:x.rstrip('km'))
data
data.to_csv('../data/curated/closest_school.csv')
# Out:
#      Unnamed: 0.1  Unnamed: 0  Postcode                  Centroid  \
# 0               0           1      3000     -37.817403 144.956776
# 1               1           4      3003     -37.810871 144.949592
# 2               2           6      3004     -37.844246 144.970161
# 3               3           9      3006  -37.82528675 144.9520744
# 4               4          11      3008     -37.814719 144.948039
# ..            ...         ...       ...                       ...
# 568           568        2279      3987     -38.309048 145.689142
# 569           569        2280      3988     -38.313447 145.811863
# 570           570        2281      3992     -38.569135 145.534315
# 571           571        2287      3995     -38.578071 145.630713
# 572           572        2288      3996     -38.629561 145.745609
#
#                         School_Name                    Address  \
# 0                    Ozford College               Levels 7 & 9
# ...
