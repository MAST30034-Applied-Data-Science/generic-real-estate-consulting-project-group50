# %%
import pandas as pd
import geopandas as gpd

# read the shape file
sf = gpd.read_file("../data/raw/PTV_METRO_BUS_STOP.shp")

sf.head()
# Out:
#   STOP_ID                                          STOP_NAME   LATITUDE  \
# 0   10185       Bonnie View Rd/Maroondah Hwy (Croydon North) -37.780920
# 1   10186          Primrose Rd/Maroondah Hwy (Croydon North) -37.774626
# 2   10187            Exeter Rd/Maroondah Hwy (Croydon North) -37.770446
# 3   10188  Maroondah Golf Park/Maroondah Hwy (Chirnside P... -37.766346
# 4   10189    Old Melbourne Rd/Maroondah Hwy (Chirnside Park) -37.765276
#
#     LONGITUDE TICKETZONE ROUTEUSSP                        geometry
# 0  145.288145          2       670  POINT (349252.545 5817113.477)
# 1  145.292843          2       670  POINT (349653.536 5817819.423)
# 2  145.295459          2       670  POINT (349875.465 5818287.445)
# 3  145.301775          2       670  POINT (350423.536 5818752.496)
# 4  145.304410          2       670  POINT (350653.473 5818875.436)

# %%
sf = sf.iloc[672:1366]

sf
# Out:
#      STOP_ID                                          STOP_NAME   LATITUDE  \
# 672    10376              Atheldene Dr/Gillespie Rd (St Albans) -37.734929
# 673    10377                  Andrew Rd/Jamieson St (St Albans) -37.736117
# 674    10378                    John St/Jamieson St (St Albans) -37.738941
# 675     1038                  Andrew St/Bastings St (Northcote) -37.774426
# 676    10381                 Parnell St/Bernard St (Cheltenham) -37.953395
# ...      ...                                                ...        ...
# 1361   11150             The Avenue/Station St (Ferntree Gully) -37.883259
# 1362   11151  Mountain Gate SC/Ferntree Gully Rd (Ferntree G... -37.883363
# 1363   11153     Merlynston Station/Lorensen Ave (Coburg North) -37.721406
# 1364   11154            Pearcedale Rd/Robinsons Rd (Pearcedale) -38.187184
# 1365   11155             Victoria Rd/Pearcedale Rd (Pearcedale) -38.195650
#
#        LONGITUDE TICKETZONE    ROUTEUSSP                        geometry
# 672   144.788918          2          425  POINT (305164.489 5821294.517)
# 673   144.788826          2          425  POINT (305159.482 5821162.495)
# 674   144.787051          2          425  POINT (305010.485 5820845.421)
# 675   145.003249          1          567  POINT (324146.497 5817336.432)
# 676   145.062852          2  812,821,811  POINT (329808.528 5797587.518)
# ...          ...        ...          ...                             ...
# 1361  145.295352          2      693,691  POINT (350094.515 5805769.417)
# 1362  145.275303          2          693  POINT (348331.487 5805725.460)
# 1363  144.960495        1,2          534  POINT (320252.495 5823138.517)
# 1364  145.237414          2          776  POINT (345638.517 5771949.529)
# 1365  145.236444          2      792,776  POINT (345571.460 5771008.452)
#
# [694 rows x 7 columns]

# %%
# Convert the geometry shaape to to latitude and longitude
# Please attribute this if you are using it
sf['geometry'] = sf['geometry'].to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")
sf.head()
# Out:
#     STOP_ID                              STOP_NAME   LATITUDE   LONGITUDE  \
# 672   10376  Atheldene Dr/Gillespie Rd (St Albans) -37.734929  144.788918
# 673   10377      Andrew Rd/Jamieson St (St Albans) -37.736117  144.788826
# 674   10378        John St/Jamieson St (St Albans) -37.738941  144.787051
# 675    1038      Andrew St/Bastings St (Northcote) -37.774426  145.003249
# 676   10381     Parnell St/Bernard St (Cheltenham) -37.953395  145.062852
#
#     TICKETZONE    ROUTEUSSP                     geometry
# 672          2          425  POINT (144.78892 -37.73492)
# 673          2          425  POINT (144.78883 -37.73610)
# 674          2          425  POINT (144.78706 -37.73893)
# 675          1          567  POINT (145.00326 -37.77441)
# 676          2  812,821,811  POINT (145.06286 -37.95338)

# %%
# create a JSON 
geoJSON = sf['geometry'].to_json()

# print the first 300 chars of the json
print(geoJSON[:300])
# Out:
# {"type": "FeatureCollection", "features": [{"id": "672", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [144.7889240153727, -37.73491583507863]}, "bbox": [144.7889240153727, -37.73491583507863, 144.7889240153727, -37.73491583507863]}, {"id": "673", "type": "Feature

# %%
import folium

_map = folium.Map(location=[143.73, -37.56], tiles="Stamen Terrain", zoom_start=10)

# refer to the folium documentations on how to plot aggregated data.
_map.add_child(folium.Choropleth(
    geo_data=geoJSON,
    name='choropleth',
))

_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbb36d93a7d1841ca9a30da0955c6b88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbb36d93a7d1841ca9a30da0955c6b88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cbb36d93a7d1841ca9a30da0955c6b88 = L.map(
#                 &quot;map_cbb36d93a7d1841ca9a30da0955c6b88&quot;,
#                 {
#                     center: [143.73, -37.56],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1be24eb71f7287eebaf14089e4dd667b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cbb36d93a7d1841ca9a30da0955c6b88);
#
#
#             var choropleth_0c4e36af358fd1ddcd30129a3e1a896a = L.featureGroup(
#                 {}
#             ).addTo(map_cbb36d93a7d1841ca9a30da0955c6b88);
#
#
#         function geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ef01b05083fb2c859ae7c29d0e67eeeb = L.geoJson(null, {
#                 onEachFeature: geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_onEachFeature,
#
#                 style: geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_styler,
#         });
#
#         function geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_add (data) {
#             geo_json_ef01b05083fb2c859ae7c29d0e67eeeb
#                 .addData(data)
#                 .addTo(choropleth_0c4e36af358fd1ddcd30129a3e1a896a);
#         }
#             geo_json_ef01b05083fb2c859ae7c29d0e67eeeb_add({&quot;bbox&quot;: [144.547362982812, -38.253464804469125, 145.35228573850543, -37.6595357797981], &quot;features&quot;: [{&quot;bbox&quot;: [144.7889240153727, -37.73491583507863, 144.7889240153727, -37.73491583507863], &quot;geometry&quot;: {&quot;coordinates&quot;: [144.7889240153727, -37.73491583507863], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;672&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [144.78883185526126, -37.73610383507975, 144.78883185526126, -37.73610383507975], &quot;geometry&quot;: {&quot;coordinates&quot;: [144.78883185526126, -37.73610383507975], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;673&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [144.78705705526602, -37.738927854977256, 144.78705705526602, -37.738927854977256], &quot;geometry&quot;: {&quot;coordinates&quot;: [144.78705705526602, -37.738927854977256], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;674&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [145.00325501396355, -37.774412799913854, 145.00325501396355, -37.774412799913854], &quot;geometry&quot;: {&quot;coordinates&quot;: [145.00325501396355, -37.774412799913854], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;675&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [145.0628580240545, -37.953381855113484, 145.0628580240545, -37.953381855113484], &quot;geometry&quot;: {&quot;coordinates&quot;: [145.0628580240545, -37.953381855113484], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;676&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [145.06484198367716, -37.953666885251685, 145.06484198367716, -37.953666885251685], &quot;geometry&quot;: {&quot;coordinates&quot;: [145.06484198367716, -37.953666885251685], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;677&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [145.0675527831668, -37.954008885440246, 145.0675527831668, -37.954008885440246], &quot;geometry&quot;: {&quot;coordinates&quot;: [145.0675527831668, -37.954008885440246], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;678&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [145.07159090240563, -37.954525845721236, 145.07159090240563, -37.954525845721236], &quot;geometry&quot;: {&quot;coordinates&quot;: [145.07159090240563, -37.954525845721236], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;679&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [14
