# %%
#download historical data by URL
import pandas as pd
workbook_url = 'https://www.dhhs.vic.gov.au/moving-annual-rents-suburb-march-quarter-2021-excel'
def combine_func(workbook_url):
    all_df = pd.read_excel(workbook_url, sheet_name=None)
    df = pd.concat(all_df, ignore_index=True)
    return df
combine_func(workbook_url)
# Out:
#      Suburbs by region: Moving annual median rent  \
# 0                                  1 bedroom flat
# 1                                             NaN
# 2                                             NaN
# 3                                 Inner Melbourne
# 4                                             NaN
# ...                                           ...
# 1129                                          NaN
# 1130                                          NaN
# 1131                                          NaN
# 1132                                          NaN
# 1133                                          NaN
#
#                                  Unnamed: 1                       Unnamed: 2  \
# 0                                       NaN  Lease commenced in year ending
# 1                                       NaN                         Mar 2000
# 2                                       NaN                            Count
# ...
