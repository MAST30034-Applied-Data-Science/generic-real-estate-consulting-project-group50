# %%
import pandas as pd

complete_data = pd.read_csv("../data/curated/complete_data.csv")

complete_data.head(10)
# Out:
# /var/folders/3g/dvm9s8n56db3kbscpvrh4pzc0000gn/T/ipykernel_89816/2145845022.py:3: DtypeWarning: Columns (11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   complete_data = pd.read_csv("../data/curated/complete_data.csv")
#    Unnamed: 0  Postcode                             Property Address  \
# 0           0      3000       CP2008/11 Rose Lane Melbourne VIC 3000
# 1           1      3000       CP2008/11 Rose Lane Melbourne VIC 3000
# 2           2      3000       CP2008/11 Rose Lane Melbourne VIC 3000
# 3           3      3000       CP2008/11 Rose Lane Melbourne VIC 3000
# 4           4      3000       CP2008/11 Rose Lane Melbourne VIC 3000
# 5           5      3000  Unit 1713/200 Spencer St Melbourne VIC 3000
# 6           6      3000  Unit 1713/200 Spencer St Melbourne VIC 3000
# 7           7      3000  Unit 1713/200 Spencer St Melbourne VIC 3000
# 8           8      3000  Unit 1713/200 Spencer St Melbourne VIC 3000
# ...

# %%
data = complete_data[['Postcode','Baths','Population', 'Count_School', 'Count_Station','Bedrooms','Weekly Rental Price']]
data['Count_School'] = data['Count_School'].fillna(0)
data['Count_Station'] = data['Count_Station'].fillna(0)
data = data.dropna(axis=0)

data.head(10)
# Out:
# /var/folders/3g/dvm9s8n56db3kbscpvrh4pzc0000gn/T/ipykernel_89816/2918337103.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Count_School'] = data['Count_School'].fillna(0)
# /var/folders/3g/dvm9s8n56db3kbscpvrh4pzc0000gn/T/ipykernel_89816/2918337103.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Count_Station'] = data['Count_Station'].fillna(0)
#    Postcode  Baths    Population  Count_School  Count_Station  Bedrooms  \
# ...

# %%
data = data[(data['Baths'] > 0) & (data['Bedrooms'] > 0)]

data.head(10)
# Out:
#     Postcode  Baths    Population  Count_School  Count_Station  Bedrooms  \
# 5       3000      1  34652.148872           4.0           45.0         1
# 6       3000      1  34652.148872           4.0           45.0         1
# 7       3000      1  34652.148872           4.0           45.0         1
# 8       3000      1  34652.148872           4.0           45.0         1
# 9       3000      1  34652.148872           4.0           45.0         1
# 10      3000      2  34652.148872           4.0           45.0         2
# 11      3000      2  34652.148872           4.0           45.0         2
# 12      3000      2  34652.148872           4.0           45.0         2
# 13      3000      2  34652.148872           4.0           45.0         2
# 14      3000      2  34652.148872           4.0           45.0         2
#
#     Weekly Rental Price
# 5                 440.0
# 6                 440.0
# 7                 440.0
# 8                 440.0
# 9                 440.0
# ...

# %%
x_train = data[['Postcode','Baths','Population', 'Count_School', 'Count_Station','Bedrooms']]
y_train = data['Weekly Rental Price']

# %%
from sklearn.model_selection import train_test_split

# split the data into two groups that are training set and the testing set
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(x_train, y_train, test_size=0.3, shuffle=True)

# %%
# import the random forest regressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [3000, 4000, 5000, 6000, 7000],
    "max_features": ["sqrt", "log2"],
    "bootstrap": [True, False],
    "min_samples_split" : [2,4,8]
}

regr = RandomForestRegressor(random_state=42)

rf = GridSearchCV(regr, parameters)
rf.fit(x_train, y_train)

print(rf.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/yuanli/Desktop/Applied Data Science/Project 2/generic-real-estate-consulting-project-group50/draft works/random_forest_regressor.ipynb Cell 6 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/Users/yuanli/Desktop/Applied%20Data%20Science/Project%202/generic-real-estate-consulting-project-group50/draft%20works/random_forest_regressor.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> regr = RandomForestRegressor(random_state=42)
#      <a href='vscode-notebook-cell:/Users/yuanli/Desktop/Applied%20Data%20Science/Project%202/generic-real-estate-consulting-project-group50/draft%20works/random_forest_regressor.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a> rf = GridSearchCV(regr, parameters)
# ...

# %%
# import the random forest regressor
from sklearn.ensemble import RandomForestRegressor

# instantiate model with 200 decision trees
rf = RandomForestRegressor(n_estimators = 5000, max_features = 'log2', bootstrap =  True, random_state = 42)

# train the model on training data
rf.fit(x_train_split, y_train_split)
# Out:
# RandomForestRegressor(max_features='log2', n_estimators=5000, random_state=42)

# %%
# use the forest's predict method on the test data
predictions = rf.predict(x_test_split)

# %%
import numpy as np

# calculate the absolute errors
error = predictions - y_test_split
error = [abs(x) for x in error]

# print out the mean absolute error (mae)
np.mean(error)
# Out:
# 73.24638100376195

# %%
from statistics import mode

# calculate the absolute errors of baseline model
y_mode = mode(y_test_split)
baseline_error = [abs(y_mode-x) for x in y_test_split]
np.mean(baseline_error)
# Out:
# 140.6040072827361

# %%
import matplotlib.pyplot as plt

# plot the true amount of trips and the predictions of the random forest regressor and xgboost regressor
plt.title('Result Analysis')
plt.plot(x_test_split.index, y_test_split, color = 'red', label = 'true value')
plt.plot(x_test_split.index, predictions, color = 'green', label = 'random forest regressor prediction')

plt.legend()
plt.xlabel('Postcode')
plt.ylabel('Weekly Rent')
plt.title('1')

# save the histogram
# plt.savefig('../plots/result_analysis')

plt.show()
