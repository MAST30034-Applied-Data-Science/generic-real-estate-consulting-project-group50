# %%
import pandas as pd

shopping = pd.read_csv('../data/raw/shopping_center.csv')

shopping
# Out:
#                                    title  \
# 0                      206 BOURKE STREET
# 1           ACLAND COURT SHOPPING CENTRE
# 2            ALTONA GATE SHOPPING CENTRE
# 3     BALNARRING VILLAGE SHOPPING CENTRE
# 4                          BARKLY SQUARE
# ..                                   ...
# 186                        WODONGA PLAZA
# 187            WOODGROVE SHOPPING CENTRE
# 188     WOOLWORTHS WHITEBOX RISE WODONGA
# 189  WYNDHAM VALE SQUARE SHOPPING CENTRE
# 190      WYNDHAM VILLAGE SHOPPING CENTRE
#
#                                                    url  \
# 0    https://www.australia-shoppings.com/malls-cent...
# 1    https://www.australia-shoppings.com/malls-cent...
# 2    https://www.australia-shoppings.com/malls-cent...
# 3    https://www.australia-shoppings.com/malls-cent...
# 4    https://www.australia-shoppings.com/malls-cent...
# ..                                                 ...
# 186  https://www.australia-shoppings.com/malls-cent...
# ...
